# %% [markdown]
# Step 1 : Gathering dataset

# %%
#importing the packages
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("/content/insurance.csv")

# %%
data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %% [markdown]
# Step 2 : Data cleaning

# %%
#one hot encoding  - to convert categorical variables into numerical format
data['sex']=data['sex'].apply({'male':1,'female':2}.get)

# %%
data.head()
# Out:
#    age  sex   bmi  children smoker     region  expenses
# 0   19    2  27.9         0    yes  southwest  16884.92
# 1   18    1  33.8         1     no  southeast   1725.55
# 2   28    1  33.0         3     no  southeast   4449.46
# 3   33    1  22.7         0     no  northwest  21984.47
# 4   32    1  28.9         0     no  northwest   3866.86

# %%
data['smoker']=data['smoker'].apply({'yes':1,'no':0}.get)
data['region']=data['region'].apply({'southeast':1,'southwest':2,'northeast':3,'northwest':4}.get)

# %%
data.head()
# Out:
#    age  sex   bmi  children  smoker  region  expenses
# 0   19    2  27.9         0       1       2  16884.92
# 1   18    1  33.8         1       0       1   1725.55
# 2   28    1  33.0         3       0       1   4449.46
# 3   33    1  22.7         0       0       4  21984.47
# 4   32    1  28.9         0       0       4   3866.86

# %% [markdown]
# Step 3 : Dividing the data into depenedent and independent variables

# %%
x=data[['age','sex','bmi','children','smoker','region']] #independent column
y=data['expenses'] #dependent column

# %% [markdown]
# Step 4 : Splitting the data into train and test set

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8) #means 80% data for training and 20% data for testing

# %% [markdown]
# Creating MLM using LinearRegression algorithm

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression() #activating the algorithm

# %%
regression.fit(x_train,y_train) #training the MLM with help of .fit()
# Out:
# LinearRegression()

# %%
predictions=regression.predict(x_test) #future predictions by MLM

# %%
print(predictions)
# Out:
# [ 2188.24637838  6814.86810805 16230.18687602  6085.2569949
#   1933.45501505  6672.8276759   7347.21623406 17673.26956205
#  15958.1784713   5384.09523567 34993.5684407   3911.41850725
#  11924.30045011  8367.90817916 30475.45332721  9298.49481296
#  35631.88130098 11708.41668386 14360.83448602 12355.91691763
#  11904.04809843  4041.70798882 -1238.03592166 14856.95837153
#  12382.87967189  6742.55917447  9574.76898185 29679.00234587
#  10529.6388287   6007.62480965  9110.85265049 10917.14475061
#   8979.33537251  1410.51205519  7984.27124178 11846.32551289
#  37015.83287249 10709.2741369   5854.79121965  8304.66897339
#   7917.22362345  3180.55303979 33161.67410823 15523.66785104
#  34153.97992885  4421.21766212 17603.52504636 17561.96939978
#  14480.14209733  9661.80062976 11189.43015551 38867.78702887
#   6837.69407937 28954.78236998  7281.60332149 15015.32296333
#   1623.62144818 34176.84859231  4065.83100659  5806.46459852
#  13195.50109044 29999.52206221 29253.79887857  9043.71212771
#  12999.68148714 29901.6497016  36624.25371418 12380.1265416
#   8265.9647874   6236.79004019 17344.78074978  7407.60831828
#   1694.88948107  5426.78927246   226.4524826  10805.82723219
#   9526.33125932  5520.85587798  8288.77203811  1698.83807528
#   6824.35638215 10757.6102769  27908.77530633 16698.39287199
#  27649.96609874  7473.42982176  4500.27937331  3416.72498847
#  30640.39331976  5762.24813133  9464.66694096 28422.41604703
#   3163.18797945 14729.76309065 38136.78740036  3273.09612811
#   7520.23376648  4894.49737937 29754.06440974 33977.00110222
#  39429.70767664  5747.36956076 33522.44756198  5493.84556886
#   9531.92146863 37042.6614657  14202.73387728 25091.19590359
#  13611.15571167 25567.20425593  6167.18752284  7477.45550331
#   6015.65013851 11437.30336612  1120.93168079 10340.57497759
#   4231.93388455 15334.52257356 11236.15183307  7772.27465698
#   6104.15340973 13473.12794395  2841.47881981  7182.27973976
#  16928.92271746 33797.15370485  9522.31509663  9546.58879082
#  26456.36506515 32265.67307441  3899.42288899  7292.19222746
#  10792.42294239 25236.09563363 11808.98244358 26977.97658336
#   7431.69382373 10481.22476058  7172.94952715 -1221.93557528
#   3261.08203525  7199.63962028 13245.01365663  3431.39231066
#   6106.89870273  8901.43570595 31139.33958561 28991.06231974
#   6956.92376256 14309.8196456   6680.89835437  9321.2276338
#   5043.39759752  4520.38972665  3096.27886121  3951.78471053
#   9130.92983056  2296.82658364 30513.14264674 18279.43141823
#   6274.38575702 13286.82240296 34005.00178259 10906.49093364
#   9062.54474997 13426.23602858 17042.84353055 11051.17073722
#    333.52873206 11491.01678548 30197.92746147 35728.44657259
#   3401.8140854  12148.12857107  1674.57305917 10644.92075847
#  12526.30596194  7973.56035109  9145.56807248  8658.7155092
#  28783.00914934  4282.94956576 11625.05662999  8532.85251075
#   6126.94330428 38517.60111663 10391.41174291  6167.11477454
#   6792.06085734 17557.96107438  3313.32817034 34646.0859701
#   -567.51634801 31890.25399366 29295.48434717 31498.79079946
#  13508.08428936  8218.96610967 12023.41977996  9994.45012542
#   4704.05505543  5760.71593606 10404.77852039  6200.56716414
#   4367.56481473 31934.4995411   6979.92574628  9181.85670032
#  15164.20012183  5567.59057265 26527.56902782 11680.13032524
#   -976.4649057  14226.86907138  4718.86437596 10422.27690099
#   4119.47083687 27194.07593704 11040.45285003 11173.24754197
#   7872.84391495  5825.07967413  5803.64221818 27616.44012006
#   5744.81900077  3281.19154781  7151.38742901  4638.4660433
#  11661.41450787  3133.81834511  -115.71677886  6889.88048327
#   5463.00780946 39043.28503045 14289.8434533   9160.44314481
#   2751.62045252  -162.58129555 11806.3012208  27558.70185994
#  33321.20858194 31632.89037515  8755.3730905   5851.96799853
#   8161.30927592  3953.00298808 15160.25152761   -79.5017401
#   6328.16758563  9144.38730725 15510.18213487 30316.00461891
#  14951.03365512  6073.17715025 34194.07347099  5067.50455215
#  38753.80130478  2570.44861001  7333.8092868   6088.00662694
#  12112.04853416 12873.78759176 30971.7746032  33653.78882755
#   8295.27035152  4493.63906156 32327.3555897  10882.28648949]

# %%
regression.score(x,y)
# Out:
# 0.7501606383983278

# %% [markdown]
# predictions on top of new dataset

# %%
data_new={'age':65,'sex':1,'bmi':25,'children':3,'smoker':0,'region':2}
index=[1] #serial number

# %%
my_data=pd.DataFrame(data_new,index)

# %%
my_data
# Out:
#    age  sex  bmi  children  smoker  region
# 1   65    1   25         3       0       2

# %%
new_predictions=regression.predict(my_data)

# %%
print("the health insurance cost for the new customer is",new_predictions)
# Out:
# the health insurance cost for the new customer is [13966.65483306]

# %% [markdown]
# Ridge regression

# %%
from sklearn.linear_model import Ridge
ridge=Ridge(alpha=1)
ridge.fit(x_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
predictions_ridge=ridge.predict(x_test)

# %%
ridge.score(x,y)
# Out:
# 0.7501240308717474

# %% [markdown]
# Lasso regression

# %%
from sklearn.linear_model import Lasso
lasso=Lasso(alpha=1)
lasso.fit(x_train,y_train)
# Out:
# Lasso(alpha=1)

# %%
predictions_lasso=lasso.predict(x_test)

# %%
lasso.score(x,y)
# Out:
# 0.750162189502124
