# %%
import pandas as pd
import numpy as np

data=pd.read_csv("/content/BankNote_Authentication.csv")
data.head()
# Out:
#    variance  skewness  curtosis  entropy  class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %%
x=data[['variance','skewness','curtosis','entropy']]
y=data['class']

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split (x,y,train_size=0.8)

from sklearn.tree import DecisionTreeClassifier
tree_classfier=DecisionTreeClassifier()

tree_classfier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=tree_classfier.predict(x_test)

from sklearn.metrics import  confusion_matrix, accuracy_score
cm=confusion_matrix(y_test,y_pred)
ac=accuracy_score(y_test,y_pred)

# %%
print(cm)
# Out:
# [[150   1]
#  [  2 122]]

# %%
print(ac)
# Out:
# 0.9890909090909091

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()
classifier.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
classifier_pred=classifier.predict(x_test)
cm=confusion_matrix(y_test,classifier_pred)
ac=accuracy_score(y_test,classifier_pred)

# %%
print(cm)
# Out:
# [[150   1]
#  [  0 124]]

# %%
print(ac)
# Out:
# 0.9963636363636363

# %% [markdown]
# NEW DATA

# %%
import pandas as pd
import numpy as np

new_data={'variance':3.7,'skewness':8.9,'curtosis':-2.5,'entropy':-0.5}
index=[1]
my_data=pd.DataFrame(new_data,index)

new_pred=tree_classfier.predict(my_data)

print("The new Bank note is",new_pred)
# Out:
# The new Bank note is [0]
